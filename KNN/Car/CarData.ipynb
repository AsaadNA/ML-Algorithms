# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %matplotlib inline

# %%
df = pd.read_csv('car_data.csv',index_col=0)
df.head()
# Out:
#           make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two  convertible          rwd
# 3  alfa-romero       gas        std          two    hatchback          rwd
# 4         audi       gas        std         four        sedan          fwd
# 5         audi       gas        std         four        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_type  \
# 1           front        88.6   168.8   64.1  ...         dohc
# 2           front        88.6   168.8   64.1  ...         dohc
# 3           front        94.5   171.2   65.5  ...         ohcv
# 4           front        99.8   176.6   66.2  ...          ohc
# 5           front        99.4   176.6   66.4  ...          ohc
#
#    num_of_cylinders engine_size fuel_system  compression_ratio horsepower  \
# ...

# %%
#First what we need to do is clean up the dataset
df = df.drop(['wheel_base','length','width','height','curb_weight','engine_type','num_of_cylinders' , 'engine_size' , 'fuel_system' , 'compression_ratio','horsepower','peak_rpm','city_mpg' , 'highway_mpg'] , axis="columns")
df
# Out:
#             make fuel_type aspiration num_of_doors   body_style drive_wheels  \
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two  convertible          rwd
# 3    alfa-romero       gas        std          two    hatchback          rwd
# 4           audi       gas        std         four        sedan          fwd
# 5           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 201        volvo       gas        std         four        sedan          rwd
# 202        volvo       gas      turbo         four        sedan          rwd
# 203        volvo       gas        std         four        sedan          rwd
# 204        volvo    diesel      turbo         four        sedan          rwd
# 205        volvo       gas      turbo         four        sedan          rwd
#
#     engine_location  price
# ...
